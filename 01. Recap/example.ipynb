# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.normal(1,2, size = (1000,500))

# %%
_ = plt.hist(x.mean(axis = 0), bins = 40)

# %%
x = np.random.exponential(3, size = (1000,500))
_ = plt.hist(x.mean(axis = 0), bins = 40)

# %%
x = np.random.lognormal(1,2, size = 500)

# %%
_ = plt.hist(np.random.lognormal(1,2, size = (1000,500)).mean(axis = 0), bins = 20)

# %%
sorted(x)
# Out:
# [0.0037666890335754117,
#  0.012456076107054528,
#  0.020897267347335702,
#  0.02162054722709353,
#  0.022424143866781016,
#  0.03363191166786651,
#  0.0381375383097799,
#  0.03876718299500938,
#  0.05361017463023142,
#  0.06353045626296544,
#  0.06641608293751936,
#  0.07020641544362304,
#  0.07209178593177548,
#  0.07358700722800286,
#  0.07468072015153818,
#  0.07648384749441292,
#  0.07923067167143756,
#  0.08081221011930045,
#  0.08273300672720167,
#  0.08554040948559578,
#  0.09446557324668332,
#  0.0953451739100867,
#  0.10147526872435922,
#  0.1014753212063419,
#  0.10260572192329546,
#  0.11031546144875164,
#  0.11518818349286858,
#  0.11767290023987297,
#  0.12089373574031641,
#  0.12574715335131412,
#  0.12920631029380483,
#  0.1297799790044759,
#  0.13250058585312854,
#  0.1392155236334514,
#  0.14821313764133676,
#  0.15614672063127868,
#  0.16465660755751546,
#  0.16470104720274656,
#  0.17018433045152526,
#  0.1706598926603992,
#  0.1725808636687854,
# ...

# %%
_ = plt.hist(np.random.standard_cauchy(size = 500))

# %%
_ = plt.hist(np.random.standard_cauchy(size = (1000,500)).mean(axis = 0))
